# %% [markdown]
# # API usage examples
# ***

# %%
import pystac
import requests

from datetime import datetime
from pathlib import Path


def get(endpoint, params=None):
    response = requests.get(endpoint, params=params)
    if response.status_code == 200:
        return response.json()
    print(f"error: {response.text}")
    return None

def download_asset(url, download_path):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(download_path, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"downloaded in {download_path}")
        return True
    print(f"error downloading file {url}: {response.text}")
    return False


STAC_API_URL = "https://terrabrasilis.dpi.inpe.br/stac-api/v1/"
# API documentation: https://terrabrasilis.dpi.inpe.br/stac-api/v1/docs

# %% [markdown]
# ## collections
# ***

# %%
# https://terrabrasilis.dpi.inpe.br/stac-api/v1/collections
endpoint = f"{STAC_API_URL}/collections"
res = get(endpoint=endpoint)
for collection in res["collections"]:
    print(f"\ncollection: {collection['id']} - {collection['description']}")
    print(collection)
# Out:
# collection: collection1 - configuração inicial
# {'type': 'Collection', 'id': 'collection1', 'stac_version': '1.0.0', 'description': 'configuração inicial', 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2018/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2019/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2020/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2021/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2022/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2023/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2024/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/collection.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}], 'stac_extensions': ['https://stac-extensions.github.io/item-assets/v1.0.0/schema.json'], 'item-assets': {'Nuvem': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'Nuvem', 'description': 'Área de nuvem calculada por quinzena, com base nas imagens de satélite usadas pelo DETER. Dados de satélite - INPE'}, 'A7Q': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'A7Q', 'description': 'Área média de alertas de desmatamento das 3 quinzenas antes e 3 quinzenas depois da quinzena de referência e a própria quinzena nos anos anteriores. DETER - classes de desmatamento - INPE'}, 'AcAr': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'AcAr', 'description': 'Área quinzenal acumulada de alertas de desmatamento calculada até a quinzena de referência. DETER - classes de desmatamento - INPE'}, 'ArDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ArDS', 'description': 'Área de alertas de desmatamento calculada por quinzena. - DETER - classes de desmatamento - INPE'}, 'OcDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'OcDS', 'description': 'Ocorrência de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}, 'CtDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CtDS', 'description': 'Contagem de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}, 'DeAr': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DeAr', 'description': 'Diferença na área quinzenal de alertas de desmatamento calculada entre a quinzena de referência e a quinzena anterior. DETER - classes de desmatamento - INPE'}, 'XQ': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'XQ', 'description': 'XQ Média das áreas de alertas de desmatamento calculada para as quatro quinzenas anteriores. DETER - classes de desmatamento - INPE'}, 'PtDG': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'PtDG', 'description': 'Percentual de áreas degradadas calculado para a quinzena. DETER - classes de degradação - INPE'}, 'Flor': {'type': 'image/tiff; application=geotiff', 'r ...

# %% [markdown]
# ## collection
# ***

# %%
# https://terrabrasilis.dpi.inpe.br/stac-api/v1/collections/{collection_id}
endpoint = f"{STAC_API_URL}/collections/collection1"
res = get(endpoint=endpoint)
print(res)
# Out:
# {'type': 'Collection', 'id': 'collection1', 'stac_version': '1.0.0', 'description': 'configuração inicial', 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2018/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2019/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2020/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2021/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2022/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2023/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2024/catalog.json', 'type': 'application/json'}, {'rel': 'child', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/collection.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}], 'stac_extensions': ['https://stac-extensions.github.io/item-assets/v1.0.0/schema.json'], 'item-assets': {'Nuvem': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'Nuvem', 'description': 'Área de nuvem calculada por quinzena, com base nas imagens de satélite usadas pelo DETER. Dados de satélite - INPE'}, 'A7Q': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'A7Q', 'description': 'Área média de alertas de desmatamento das 3 quinzenas antes e 3 quinzenas depois da quinzena de referência e a própria quinzena nos anos anteriores. DETER - classes de desmatamento - INPE'}, 'AcAr': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'AcAr', 'description': 'Área quinzenal acumulada de alertas de desmatamento calculada até a quinzena de referência. DETER - classes de desmatamento - INPE'}, 'ArDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ArDS', 'description': 'Área de alertas de desmatamento calculada por quinzena. - DETER - classes de desmatamento - INPE'}, 'OcDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'OcDS', 'description': 'Ocorrência de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}, 'CtDS': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CtDS', 'description': 'Contagem de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}, 'DeAr': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DeAr', 'description': 'Diferença na área quinzenal de alertas de desmatamento calculada entre a quinzena de referência e a quinzena anterior. DETER - classes de desmatamento - INPE'}, 'XQ': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'XQ', 'description': 'XQ Média das áreas de alertas de desmatamento calculada para as quatro quinzenas anteriores. DETER - classes de desmatamento - INPE'}, 'PtDG': {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'PtDG', 'description': 'Percentual de áreas degradadas calculado para a quinzena. DETER - classes de degradação - INPE'}, 'Flor': {'type': 'image/tiff; application=geotiff', 'r ...

# %% [markdown]
# ## assets

# %%
# https://terrabrasilis.dpi.inpe.br/stac-api/v1/collections/{collection_id}
endpoint = f"{STAC_API_URL}/collections/collection1"
res = get(endpoint=endpoint)
for asset in res["item-assets"].values():
    print(f"\nasset: {asset['title']} - {asset['description']}")
    print(asset)
# Out:
# asset: Nuvem - Área de nuvem calculada por quinzena, com base nas imagens de satélite usadas pelo DETER. Dados de satélite - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'Nuvem', 'description': 'Área de nuvem calculada por quinzena, com base nas imagens de satélite usadas pelo DETER. Dados de satélite - INPE'}
#
# asset: A7Q - Área média de alertas de desmatamento das 3 quinzenas antes e 3 quinzenas depois da quinzena de referência e a própria quinzena nos anos anteriores. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'A7Q', 'description': 'Área média de alertas de desmatamento das 3 quinzenas antes e 3 quinzenas depois da quinzena de referência e a própria quinzena nos anos anteriores. DETER - classes de desmatamento - INPE'}
#
# asset: AcAr - Área quinzenal acumulada de alertas de desmatamento calculada até a quinzena de referência. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'AcAr', 'description': 'Área quinzenal acumulada de alertas de desmatamento calculada até a quinzena de referência. DETER - classes de desmatamento - INPE'}
#
# asset: ArDS - Área de alertas de desmatamento calculada por quinzena. - DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ArDS', 'description': 'Área de alertas de desmatamento calculada por quinzena. - DETER - classes de desmatamento - INPE'}
#
# asset: OcDS - Ocorrência de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'OcDS', 'description': 'Ocorrência de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}
#
# asset: CtDS - Contagem de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CtDS', 'description': 'Contagem de alertas de desmatamento por quinzena. DETER - classes de desmatamento - INPE'}
#
# asset: DeAr - Diferença na área quinzenal de alertas de desmatamento calculada entre a quinzena de referência e a quinzena anterior. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DeAr', 'description': 'Diferença na área quinzenal de alertas de desmatamento calculada entre a quinzena de referência e a quinzena anterior. DETER - classes de desmatamento - INPE'}
#
# asset: XQ - XQ Média das áreas de alertas de desmatamento calculada para as quatro quinzenas anteriores. DETER - classes de desmatamento - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'XQ', 'description': 'XQ Média das áreas de alertas de desmatamento calculada para as quatro quinzenas anteriores. DETER - classes de desmatamento - INPE'}
#
# asset: PtDG - Percentual de áreas degradadas calculado para a quinzena. DETER - classes de degradação - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'PtDG', 'description': 'Percentual de áreas degradadas calculado para a quinzena. DETER - classes de degradação - INPE'}
#
# asset: Flor - Área de vegetação florestal disponível e calculada para a quinzena. PRODES - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'Flor', 'description': 'Área de vegetação florestal disponível e calculada para a quinzena. PRODES - INPE'}
#
# asset: Pr - Precipitação na quinzena. Dados biofísicos - MERGE/CPTEC - INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'Pr', 'description': 'Precipitação na quinzena. Dados biofísicos - MERGE/CPTEC - INPE'}
#
# asset: NuAI - Número de autos de infração relacionados ao desmatamento calculado por quinzena. Fiscalização - PAMGIA IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'NuAI', 'description': 'Número de autos de infração relacionados ao desmatamento calculado por quinzena. Fiscalização - PAMGIA IBAMA'}
#
# asset: DeAI - Derivada do número de autos de infração relacionados ao desmatamento calculado por quinzena. Fiscalização - PAMGIA - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DeAI', 'description': 'Derivada do número de autos de infração relacionados ao desmatamento calculado por quinzena. Fiscalização - PAMGIA - IBAMA'}
#
# asset: PtEM - Porcentagem de área embargadas relacionadas ao desmatamento calculado para a quinzena. Fiscalização - PAMGIA IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'PtEM', 'description': 'Porcentagem de área embargadas relacionadas ao desmatamento calculado para a quinzena. Fiscalização - PAMGIA IBAMA'}
#
# asset: ACCESSCITY - Acessibilidade para cada 200m² em toda a Amazônia brasileira a partir de áreas urbanas, na estação chuvosa. Acessibilidade - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ACCESSCITY', 'description': 'Acessibilidade para cada 200m² em toda a Amazônia brasileira a partir de áreas urbanas, na estação chuvosa. Acessibilidade - IBAMA'}
#
# asset: ACCESSBEEF - Tempo para chegar aos frigoríficos mais próximos, na estação chuvosa. Acessibilidade - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ACCESSBEEF', 'description': 'Tempo para chegar aos frigoríficos mais próximos, na estação chuvosa. Acessibilidade - IBAMA'}
#
# asset: ACCESSSOY - Tempo para chegar aos silos mais próximos e outras infraestruturas de grãos, na estação chuvosa. Acessibilidade - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ACCESSSOY', 'description': 'Tempo para chegar aos silos mais próximos e outras infraestruturas de grãos, na estação chuvosa. Acessibilidade - IBAMA'}
#
# asset: ACCESSSOY25 - Tempo  para chegar aos silos mais próximos e outras infraestruturas de grãos com capacidade acima de 25.000 toneladas, na estação chuvosa. Acessibilidade - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ACCESSSOY25', 'description': 'Tempo  para chegar aos silos mais próximos e outras infraestruturas de grãos com capacidade acima de 25.000 toneladas, na estação chuvosa. Acessibilidade - IBAMA'}
#
# asset: ACCESSWOOD - Tempo para chegar às serrarias mais próximas, na estação chuvosa. Acessibilidade - IBAMA
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'ACCESSWOOD', 'description': 'Tempo para chegar às serrarias mais próximas, na estação chuvosa. Acessibilidade - IBAMA'}
#
# asset: CONN_MKT - Conectividade aos principais centros de comercialização de produtos e insumos agrícolas através da rede de infraestrutura rodoviária. Acessibilidade - INPE via GPM
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CONN_MKT', 'description': 'Conectividade aos principais centros de comercialização de produtos e insumos agrícolas através da rede de infraestrutura rodoviária. Acessibilidade - INPE via GPM'}
#
# asset: CONCITY10 - Conectividade aos centros urbanos com 10 mil ou mais habitantes. Acessibilidade - INPE via GPM
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CONCITY10', 'description': 'Conectividade aos centros urbanos com 10 mil ou mais habitantes. Acessibilidade - INPE via GPM'}
#
# asset: CONCITY100 - Conectividade aos centros urbanos com 100 mil ou mais habitantes. Acessibilidade - INPE via GPM
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'CONCITY100', 'description': 'Conectividade aos centros urbanos com 100 mil ou mais habitantes. Acessibilidade - INPE via GPM'}
#
# asset: DVD - Valores médios da distância vertical à drenagem mais próxima. Dados biofísicos.
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DVD', 'description': 'Valores médios da distância vertical à drenagem mais próxima. Dados biofísicos.'}
#
# asset: DRYMONTHS - Número de meses da estação seca (valor majoritário em 625 km²). Dados biofísicos.
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DRYMONTHS', 'description': 'Número de meses da estação seca (valor majoritário em 625 km²). Dados biofísicos.'}
#
# asset: EFAMS_IND - Porcentagem da célula ocupada com a categoria fundiária classe indifinida (IND). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_IND', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe indifinida (IND). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_UC - Porcentagem da célula ocupada com a categoria fundiária classe unidade de conservação (UC). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_UC', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe unidade de conservação (UC). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_TI - Porcentagem da célula ocupada com a categoria fundiária classe terra indígena (TI). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_TI', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe terra indígena (TI). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_FPND - Porcentagem da célula ocupada com a categoria fundiária classe floresta pública não destinada (FPND). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_FPND', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe floresta pública não destinada (FPND). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_CAR - Porcentagem da célula ocupada com a categoria fundiária classe imóvel rural (CAR). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_CAR', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe imóvel rural (CAR). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_ASS - Porcentagem da célula ocupada com a categoria fundiária classe assentamento (ASS) - todos os tipos. Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_ASS', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe assentamento (ASS) - todos os tipos. Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: EFAMS_APA - Porcentagem da célula ocupada com a categoria fundiária classe áreas de proteção ambiental (APA). Dados fundiários - diversas fontes - organizado no INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'EFAMS_APA', 'description': 'Porcentagem da célula ocupada com a categoria fundiária classe áreas de proteção ambiental (APA). Dados fundiários - diversas fontes - organizado no INPE'}
#
# asset: RODOFIC - Distância da célula à Rodovias Oficiais. Acessibilidade - diversas fontes - organizado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'RODOFIC', 'description': 'Distância da célula à Rodovias Oficiais. Acessibilidade - diversas fontes - organizado pelo INPE'}
#
# asset: RODNOFIC - Distância da célula à Rodovias Não Oficiais. Acessibilidade - diversas fontes - organizado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'RODNOFIC', 'description': 'Distância da célula à Rodovias Não Oficiais. Acessibilidade - diversas fontes - organizado pelo INPE'}
#
# asset: DISTURB - Distância da célula à áreas Urbanas - sede do munícipio. Acessibilidade - diversas fontes - organizado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DISTURB', 'description': 'Distância da célula à áreas Urbanas - sede do munícipio. Acessibilidade - diversas fontes - organizado pelo INPE'}
#
# asset: DISTRIOS - Distância da célula aos rios. Acessibilidade - diversas fontes - organizado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DISTRIOS', 'description': 'Distância da célula aos rios. Acessibilidade - diversas fontes - organizado pelo INPE'}
#
# asset: DISTPORT - Distância da célula à Portos. Acessibilidade - diversas fontes - organizado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'DISTPORT', 'description': 'Distância da célula à Portos. Acessibilidade - diversas fontes - organizado pelo INPE'}
#
# asset: XGBOOST25K - Arquivo gerado pelo modelo XGBoost, primeira fase do projeto de estimativa do risco de desmatamento - dado gerado pelo INPE
# {'type': 'image/tiff; application=geotiff', 'roles': ['data'], 'title': 'XGBOOST25K', 'description': 'Arquivo gerado pelo modelo XGBoost, primeira fase do projeto de estimativa do risco de desmatamento - dado gerado pelo INPE'}

# %% [markdown]
# ## list items
# ***

# %%
# https://terrabrasilis.dpi.inpe.br/stac-api/v1/collections/{collection_id}/items
endpoint = f"{STAC_API_URL}/collections/collection1/items"
res = get(endpoint=endpoint)

for feature in res["features"]:
    print(f"\nid: {feature['id']}, date: {feature['properties']['datetime']}, assets: {', '.join(list(feature['assets'].keys()))}")
    print(feature)
# Out:
# id: 20170801, date: 2017-08-01T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170801', 'properties': {'datetime': '2017-08-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170801/20170801.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170801.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170816, date: 2017-08-16T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170816', 'properties': {'datetime': '2017-08-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170816/20170816.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170816.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170901, date: 2017-09-01T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170901', 'properties': {'datetime': '2017-09-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170901/20170901.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170901.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170916, date: 2017-09-16T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170916', 'properties': {'datetime': '2017-09-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170916/20170916.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170916.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171001, date: 2017-10-01T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171001', 'properties': {'datetime': '2017-10-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171001/20171001.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171001.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171016, date: 2017-10-16T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171016', 'properties': {'datetime': '2017-10-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171016/20171016.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171016.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171101, date: 2017-11-01T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171101', 'properties': {'datetime': '2017-11-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171101/20171101.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171116, date: 2017-11-16T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171116', 'properties': {'datetime': '2017-11-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171116/20171116.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171201, date: 2017-12-01T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171201', 'properties': {'datetime': '2017-12-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171201/20171201.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20171216, date: 2017-12-16T00:00:00Z, assets: Nuvem, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20171216', 'properties': {'datetime': '2017-12-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20171216/20171216.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2017/Nuvem20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20171216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170101, date: 2017-01-01T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, PtDG, Flor, Pr, NuAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170101', 'properties': {'datetime': '2017-01-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170101/20170101.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170101.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170116, date: 2017-01-16T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, DeAr, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170116', 'properties': {'datetime': '2017-01-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170116/20170116.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170116.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170201, date: 2017-02-01T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, DeAr, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170201', 'properties': {'datetime': '2017-02-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170201/20170201.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170201.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170216, date: 2017-02-16T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, DeAr, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170216', 'properties': {'datetime': '2017-02-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170216/20170216.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170216.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170301, date: 2017-03-01T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20170301', 'properties': {'datetime': '2017-03-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/20170301/20170301.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2017/catalog.json', 'type': 'application/json'}], 'assets': {'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/AcAr20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/ArDS20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/OcDS20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/CtDS20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/DeAr20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/XQ20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2017/PtDG20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2017/Flor20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2017/Pr20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/NuAI20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2017/DeAI20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2017/PtEM20170301.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20170316, date: 2017-03-16T00:00:00Z, assets: AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# ...
#
# id: 20250316, date: 2025-03-16T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250316', 'properties': {'datetime': '2025-03-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250316/20250316.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'A7Q': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'A7Q', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250316.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20250401, date: 2025-04-01T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250401', 'properties': {'datetime': '2025-04-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250401/20250401.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'A7Q': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'A7Q', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250401.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20250516, date: 2025-05-16T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM, XGBOOST25K
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250516', 'properties': {'datetime': '2025-05-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250516/20250516.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'A7Q': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'A7Q', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}, 'XGBOOST25K': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/forecast/XGBOOST25K20250516.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XGBOOST25K', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20250601, date: 2025-06-01T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM, XGBOOST25K
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250601', 'properties': {'datetime': '2025-06-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250601/20250601.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'A7Q': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'A7Q', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}, 'XGBOOST25K': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/forecast/XGBOOST25K20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XGBOOST25K', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}
#
# id: 20250616, date: 2025-06-16T00:00:00Z, assets: XGBOOST25K
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250616', 'properties': {'datetime': '2025-06-16T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250616/20250616.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'XGBOOST25K': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/forecast/XGBOOST25K20250616.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XGBOOST25K', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}

# %% [markdown]
# ## search
# ***

# %%
endpoint = f"{STAC_API_URL}/search"
params = {
    "collections": "collection1",
    "datetime_range": "2025-06-01/2025-06-15"
}
res = get(endpoint=endpoint, params=params)

for feature in res["features"]:
    print(f"\nid: {feature['id']}, date: {feature['properties']['datetime']}, assets: {', '.join(list(feature['assets'].keys()))}")
    print(feature)
# Out:
# id: 20250601, date: 2025-06-01T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM, XGBOOST25K
# {'type': 'Feature', 'stac_version': '1.0.0', 'id': '20250601', 'properties': {'datetime': '2025-06-01T00:00:00Z'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[6195368.0772499945, 8138773.424522042], [6195368.0772499945, 10588773.424522042], [2795368.077249995, 10588773.424522042], [2795368.077249995, 8138773.424522042], [6195368.0772499945, 8138773.424522042]]]}, 'links': [{'rel': 'root', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/catalog.json', 'type': 'application/json', 'title': 'Sistema de Predição de Desmatamento'}, {'rel': 'self', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/20250601/20250601.json', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://terrabrasilis.dpi.inpe.br/stac/catalog/collection1/2025/catalog.json', 'type': 'application/json'}], 'assets': {'Nuvem': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Nuvem', 'roles': ['data']}, 'A7Q': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'A7Q', 'roles': ['data']}, 'AcAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'AcAr', 'roles': ['data']}, 'ArDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'ArDS', 'roles': ['data']}, 'OcDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'OcDS', 'roles': ['data']}, 'CtDS': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'CtDS', 'roles': ['data']}, 'DeAr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAr', 'roles': ['data']}, 'XQ': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XQ', 'roles': ['data']}, 'PtDG': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtDG', 'roles': ['data']}, 'Flor': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Flor', 'roles': ['data']}, 'Pr': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'Pr', 'roles': ['data']}, 'NuAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'NuAI', 'roles': ['data']}, 'DeAI': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'DeAI', 'roles': ['data']}, 'PtEM': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'PtEM', 'roles': ['data']}, 'XGBOOST25K': {'href': 'https://terrabrasilis.dpi.inpe.br/stac/forecast/XGBOOST25K20250601.tif', 'type': 'image/tiff; application=geotiff', 'title': 'XGBOOST25K', 'roles': ['data']}}, 'bbox': [2795368.077249995, 8138773.424522042, 6195368.0772499945, 10588773.424522042], 'stac_extensions': [], 'collection': 'collection1'}

# %% [markdown]
# ## download
# ***

# %%
endpoint = f"{STAC_API_URL}/search"
params = {
    "collections": "collection1",
    "datetime_range": "2025-06-01/2025-06-15"
}
res = get(endpoint=endpoint, params=params)

root_download_dir = Path("/tmp/risk/from20250601_to20250615")
for feature in res['features']:
    print(f"\nid: {feature['id']}, date: {feature['properties']['datetime']}, assets: {', '.join(list(feature['assets'].keys()))}")
    for name in feature['assets']:
        asset = feature['assets'][name]
        url = asset['href']
        print(f"\n[{name}] downloading {url} ...")
        download_dir = root_download_dir / name
        download_dir.mkdir(exist_ok=True, parents=True)
        download_path = download_dir / Path(url).name
        download_asset(url=url, download_path=download_path)
# Out:
# id: 20250601, date: 2025-06-01T00:00:00Z, assets: Nuvem, A7Q, AcAr, ArDS, OcDS, CtDS, DeAr, XQ, PtDG, Flor, Pr, NuAI, DeAI, PtEM, XGBOOST25K
#
# [Nuvem] downloading https://terrabrasilis.dpi.inpe.br/stac/cmask/2025/Nuvem20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/Nuvem/Nuvem20250601.tif
#
# [A7Q] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/A7Q20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/A7Q/A7Q20250601.tif
#
# [AcAr] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/AcAr20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/AcAr/AcAr20250601.tif
#
# [ArDS] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/ArDS20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/ArDS/ArDS20250601.tif
#
# [OcDS] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/OcDS20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/OcDS/OcDS20250601.tif
#
# [CtDS] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/CtDS20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/CtDS/CtDS20250601.tif
#
# [DeAr] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/DeAr20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/DeAr/DeAr20250601.tif
#
# [XQ] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/XQ20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/XQ/XQ20250601.tif
#
# [PtDG] downloading https://terrabrasilis.dpi.inpe.br/stac/deter/2025/PtDG20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/PtDG/PtDG20250601.tif
#
# [Flor] downloading https://terrabrasilis.dpi.inpe.br/stac/prodes/2025/Flor20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/Flor/Flor20250601.tif
#
# [Pr] downloading https://terrabrasilis.dpi.inpe.br/stac/merge/2025/Pr20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/Pr/Pr20250601.tif
#
# [NuAI] downloading https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/NuAI20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/NuAI/NuAI20250601.tif
#
# [DeAI] downloading https://terrabrasilis.dpi.inpe.br/stac/infracao/2025/DeAI20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/DeAI/DeAI20250601.tif
#
# [PtEM] downloading https://terrabrasilis.dpi.inpe.br/stac/embargo/2025/PtEM20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/PtEM/PtEM20250601.tif
#
# [XGBOOST25K] downloading https://terrabrasilis.dpi.inpe.br/stac/forecast/XGBOOST25K20250601.tif ...
# downloaded in /tmp/risk/from20250601_to20250615/XGBOOST25K/XGBOOST25K20250601.tif
